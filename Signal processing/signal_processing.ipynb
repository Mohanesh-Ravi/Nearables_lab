# %% [markdown]
# # Digital Signal Processing

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

# %%
pip install numpy scipy matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\mohan\appdata\local\programs\mu editor\python\lib\site-packages (1.24.4)Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\mohan\AppData\Local\Programs\MUEDIT~1\Python\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\mohan\AppData\Local\Programs\MUEDIT~1\Python\pythonw.exe -m pip install --upgrade pip' command.
# Collecting scipy
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Collecting matplotlib
#   Downloading matplotlib-3.7.5-cp38-cp38-win_amd64.whl (7.5 MB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp38-cp38-win_amd64.whl (477 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mohan\appdata\local\programs\mu editor\python\lib\site-packages (from matplotlib) (3.0.9)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.7-cp38-cp38-win_amd64.whl (55 kB)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mohan\appdata\local\programs\mu editor\python\lib\site-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.57.0-cp38-cp38-win_amd64.whl (1.5 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\mohan\appdata\local\programs\mu editor\python\lib\site-packages (from matplotlib) (21.3)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pillow>=6.2.0
#   Downloading pillow-10.4.0-cp38-cp38-win_amd64.whl (2.6 MB)
# Collecting zipp>=3.1.0
#   Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\mohan\appdata\local\programs\mu editor\python\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: zipp, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, scipy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.57.0 importlib-resources-6.4.5 kiwisolver-1.4.7 matplotlib-3.7.5 pillow-10.4.0 scipy-1.10.1 zipp-3.20.2

# %% [markdown]
# ## Sampling and quantization

# %%
# define a signal

t = np.linspace(0,10,1000) #seconds (this is not really continuous)

#x=(0.85)^t

x = (0.85)**t 

plt.figure(figsize=(16,9)) #set the size of figure

#1. Plotting "Analog" signal
plt.subplot(2,2,1)
plt.title('Analog Signal', fontsize=20)
plt.plot(t,x, linewidth=3, label='x(t) =(0.85)^t')
plt.xlabel('t', fontsize=15)
plt.ylabel('amplitude', fontsize=15)
plt.legend(loc='upper right')



#2. Sampling and plotting of "Sampled" signal
fs =0.5 #Hz

#define samples
n=np.arrange(np.min(t),np.max(t)+1/fs,1/fs) #samples at 0.5Hz
x_s =(0.85)**n #exponential signal
